# %%
import pandas as pd 
import numpy as np 

DATASET_PATH = "/home/abdallah/CMP4-Semster2/Airbnb-Rating-Classification/data/merged_airbnb_data.csv"
df = pd.read_csv(DATASET_PATH)
df.head()
# Out:
#          id property_type        room_type  \
# 0   6901257     Apartment  Entire home/apt
# 1   6304928     Apartment  Entire home/apt
# 2   7919400     Apartment  Entire home/apt
# 3  13418779         House  Entire home/apt
# 4   3808709     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...           3.0        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...           7.0        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...           5.0        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...           4.0        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...           2.0        1.0
#
#   city host_identity_verified host_response_rate   latitude   longitude  \
# 0  NYC                      t                NaN  40.696524  -73.991617
# 1  NYC                      f               100%  40.766115  -73.989040
# ...

# %%
df['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt                                                          41310
# Private room                                                             30667
# Shared room                                                               2163
# Entire rental unit                                                         333
# Entire home                                                                327
# Room                                                                       116
# Entire townhouse                                                            39
# Entire condo                                                                27
# Entire guest suite                                                          22
# Entire guesthouse                                                           21
# Entire villa                                                                13
# Entire loft                                                                  8
# ...

# %%
df['city'].value_counts()
# Out:
# city
# NYC                       32349
# LA                        22453
# SF                         6434
# DC                         5688
# Chicago                    3719
# Boston                     3468
# Los Angeles, CA, USA        200
# San Francisco, CA, USA      200
# New York, NY, USA           200
# Chicago, IL, USA            200
# Washington, DC, USA         200
# Name: count, dtype: int64

# %%
df['host_identity_verified'].value_counts()
# Out:
# host_identity_verified
# t        49748
# f        24175
# True       958
# False       42
# Name: count, dtype: int64

# %%
df['price'].describe()
# Out:
# count    75111.000000
# mean       164.062973
# std        173.992861
# min          1.000000
# 25%         75.000000
# 50%        115.000000
# 75%        189.000000
# max       2636.000000
# Name: price, dtype: float64

# %%
df['accommodates'].value_counts()
# Out:
# accommodates
# 2.0     31940
# 4.0     12254
# 1.0      9437
# 3.0      7827
# 6.0      5171
# 5.0      3514
# 8.0      1896
# 7.0       995
# 10.0      771
# 16.0      312
# 9.0       295
# 12.0      294
# 14.0      118
# 11.0       87
# 15.0       55
# 13.0       38
# Name: count, dtype: int64

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 1.0     49966
# 2.0     11634
# 0.0      6745
# 3.0      4561
# 4.0      1445
# 5.0       395
# 6.0       117
# 7.0        42
# 8.0        14
# 10.0       10
# 9.0         8
# Name: count, dtype: int64

# %%
df['bathrooms'].value_counts()
# Out:
# bathrooms
# 1.0    58537
# 2.0     8278
# 1.5     3801
# 2.5     1567
# 3.0     1175
# 3.5      429
# 4.0      316
# 0.5      246
# 0.0      198
# 4.5      116
# 5.0       79
# 8.0       41
# 5.5       39
# 6.0       26
# 6.5       12
# 7.0       10
# 7.5        6
# Name: count, dtype: int64

# %%
df['beds'].value_counts()
# Out:
# beds
# 1.0     45268
# 2.0     16939
# 3.0      6669
# 4.0      3221
# 5.0      1392
# 6.0       709
# 7.0       242
# 8.0       203
# 10.0       91
# 9.0        76
# 16.0       38
# 12.0       30
# 11.0       26
# 13.0       12
# 15.0        6
# 14.0        4
# 0.0         4
# 18.0        1
# Name: count, dtype: int64

# %%
df['number_of_reviews'].describe()
# Out:
# count    75104.000000
# mean        22.083804
# std         42.527803
# min          0.000000
# 25%          1.000000
# 50%          6.000000
# 75%         24.000000
# max        990.000000
# Name: number_of_reviews, dtype: float64

# %%
sv = df['host_response_rate'].value_counts()
sv.to_csv("/home/abdallah/CMP4-Semster2/Airbnb-Rating-Classification/validation/host_response_rate_distribution.csv")

# %%
df['host_response_rate'].isna().sum()
# Out:
# np.int64(18355)

# %%
df['latitude'].isna().sum()
# Out:
# np.int64(2)
